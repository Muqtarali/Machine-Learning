# %% [markdown]
# <a href="https://colab.research.google.com/github/Muqtarali/Machine-Learning/blob/main/DataGathering/Working_with_CSV_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone your GitHub repository
# !git clone https://github.com/Muqtarali/Machine-Learning.git

# 2. Navigate to the specific folder
import os
os.chdir('/content/Machine-Learning/data Gathering')

# 3. Do your work and save files here
import pandas as pd
df.to_csv('Working with CSV files.csv', index=False)

# 4. Add changes to git
# !git add .

# 5. Configure git (if first time)
# !git config --global user.email "muqtarali361@gmail.com"
# !git config --global user.name "Muqtar Ali"

# 6. Commit changes
# !git commit -m "Added output files from Colab"

# 7. Push to GitHub
# !git push
# Out:
# Cloning into 'Machine-Learning'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 20 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 58.09 KiB | 5.28 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_937/541985017.py in <cell line: 0>()
#       8 # 3. Do your work and save files here
#       9 import pandas as pd
# ---> 10 df.to_csv('Working with CSV files.csv', index=False)
#      11
#      12 # 4. Add changes to git
#
# NameError: name 'df' is not defined
